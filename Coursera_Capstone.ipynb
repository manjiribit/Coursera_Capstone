# %% [markdown]
# # IBM Data Science Professional Certification
# ## Capstone Project
# 1. This Notebook will be mainly used for the capstone project.
# 2. We will be searching nearby venues of specific type and exploring a particular venue with the help of location data provider like **Foursquare**.
# 3. We will be using **k-means clustering** - *a form of unsupervised learning*.
# 4. We will be **scraping a website and parsing HTML code** using python package **Beautifulsoup**.

# %%
import pandas as pd

# %%
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
